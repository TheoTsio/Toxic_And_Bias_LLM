# %%
import requests
import json
import os

token = os.environ.get("OPENROUTER_API_KEY")

# Extract the assistant message with reasoning_details
response = response.json()
print(response)
response = response['choices'][0]['message']

# Preserve the assistant message with reasoning_details
messages = [
  {"role": "user", "content": "How many r's are in the word 'strawberry'?"},
  {
    "role": "assistant",
    "content": response.get('content'),
    "reasoning_details": response.get('reasoning_details')  # Pass back unmodified
  },
  {"role": "user", "content": "Are you sure? Think carefully."}
]

# Second API call - model continues reasoning from where it left off
response2 = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  data=json.dumps({
    "model": "qwen/qwen3.8-max",
    "messages": messages,  # Includes preserved reasoning_details
    "reasoning": {"enabled": True}
  })
)
# Out:
# {'id': 'gen-1786902409-BqZtxsh1jtR3A8TRsaK7', 'object': 'chat.completion', 'created': 1786902409, 'model': 'qwen/qwen3.8-max', 'provider': 'Alibaba', 'system_fingerprint': None, 'service_tier': None, 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'native_finish_reason': 'stop', 'message': {'role': 'assistant', 'content': 'There are **3** r’s in the word **“strawberry.”**', 'refusal': None, 'reasoning': "We need answer simple. Need produce final. User asks how many r's in strawberry. Count: s t r a w b e r r y -> r at position 3, 8, 9 = 3. Need concise.\n", 'reasoning_details': [{'type': 'reasoning.text', 'text': "We need answer simple. Need produce final. User asks how many r's in strawberry. Count: s t r a w b e r r y -> r at position 3, 8, 9 = 3. Need concise.\n", 'format': 'unknown', 'index': 0}]}}], 'usage': {'prompt_tokens': 61, 'completion_tokens': 70, 'total_tokens': 131, 'cost': 0.000542, 'is_byok': False, 'prompt_tokens_details': {'cached_tokens': 0, 'cache_write_tokens': 0, 'audio_tokens': 0, 'video_tokens': 0}, 'cost_details': {'upstream_inference_cost': 0.000542, 'upstream_inference_prompt_cost': 0.000122, 'upstream_inference_completions_cost': 0.00042}, 'completion_tokens_details': {'reasoning_tokens': 49, 'image_tokens': 0, 'audio_tokens': 0}}}
